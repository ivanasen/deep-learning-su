# %% [markdown]
# Deep Learning
# =============
#
# Assignment 3.1
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline

import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'a', 'term', 'originated', 'of', 'originated', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From /home/ivanasen/Code/Projects/deep-learning-su/assignments/assignment_3/.assignment_3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/ivanasen/Code/Projects/deep-learning-su/assignments/assignment_3/.assignment_3/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:1444: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /home/ivanasen/Code/Projects/deep-learning-su/assignments/assignment_3/.assignment_3/lib/python3.7/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.834378
# Nearest to zero: abuse, fran, throughput, chambered, aristocrats, deleuze, ihs, filename,
# Nearest to on: menstrual, thane, bioko, constrain, grenadines, konerko, organisation, prevail,
# Nearest to to: wail, polynomials, kingman, woman, misunderstood, apogee, inhuman, macquarie,
# Nearest to into: crete, result, dyskinesia, cinema, milo, revisionists, itch, polymorphic,
# Nearest to were: julius, courtroom, neoliberalism, player, nilpotent, vesalius, mayen, maastricht,
# Nearest to been: outcasts, boise, backbench, bearded, rallied, colonization, coq, easter,
# Nearest to seven: storybook, cassini, carbonation, hyperfocal, seductive, vicious, careless, forcing,
# Nearest to and: newborn, advanced, flaws, nicolas, essence, cheltenham, silt, unguided,
# Nearest to used: shades, yielded, morrison, unsustainable, fu, handball, infamously, inefficiency,
# Nearest to or: ivies, renegades, deborah, demonstrations, tipu, rabi, tarn, epp,
# Nearest to th: reisman, ararat, largest, paternalistic, chalice, turnaround, rome, kraft,
# Nearest to which: swing, crb, tsinghua, caravaggio, vend, guilty, ceilings, prefixes,
# Nearest to it: attestation, thereafter, hydrographic, postulated, ein, spotlight, baikal, specified,
# Nearest to these: har, sissy, lifeform, trios, usher, selassie, bae, subsidised,
# Nearest to by: superconductivity, yang, belleville, showered, arrives, christ, sistine, nucleosome,
# Nearest to such: minefields, polymyositis, abydos, blackburn, giant, viscous, garonne, modality,
# Average loss at step 2000: 4.365275
# Average loss at step 4000: 3.862527
# Average loss at step 6000: 3.784347
# Average loss at step 8000: 3.691159
# Average loss at step 10000: 3.617302
# Nearest to zero: nine, seven, five, eight, six, three, four, two,
# Nearest to on: in, bioko, at, against, partisan, with, worst, about,
# Nearest to to: cantilever, would, kingman, not, mcdonald, microelectronics, exiles, will,
# Nearest to into: from, ecusa, cinema, northern, crete, sponsors, ascendancy, dict,
# Nearest to were: are, was, julius, have, ceramics, elmendorf, clocking, reparation,
# Nearest to been: by, was, be, dp, ambush, gravel, norodom, vitally,
# Nearest to seven: eight, six, five, nine, three, four, zero, two,
# Nearest to and: or, who, in, s, for, tibet, superficial, homered,
# Nearest to used: allowed, condemn, judgments, rises, koza, spacecraft, exceeding, fu,
# Nearest to or: and, authoritative, mamre, than, spike, rabi, mlm, capitol,
# Nearest to th: reisman, paratroopers, one, ararat, kryptonian, hours, webb, asparagales,
# Nearest to which: this, that, now, it, also, who, he, direct,
# Nearest to it: he, this, they, there, not, which, now, palatalization,
# Nearest to these: sissy, some, funds, lymph, many, inflows, unmistakable, cambridgeshire,
# Nearest to by: was, been, as, in, with, penguins, be, takeshi,
# Nearest to such: well, viscous, known, polymyositis, modality, canetti, gregorian, aelian,
# Average loss at step 12000: 3.605507
# Average loss at step 14000: 3.570463
# Average loss at step 16000: 3.408108
# Average loss at step 18000: 3.460008
# Average loss at step 20000: 3.540995
# Nearest to zero: seven, five, six, four, three, nine, eight, two,
# Nearest to on: bioko, in, at, against, worst, grenadines, through, menstrual,
# Nearest to to: will, would, against, could, wail, can, takeshi, acls,
# Nearest to into: from, ecusa, hypnos, biennial, northern, in, by, sponsors,
# Nearest to were: are, was, have, had, reparation, is, theorizes, be,
# Nearest to been: be, dp, by, had, was, ambush, duquette, diminution,
# Nearest to seven: eight, six, nine, five, four, zero, three, two,
# Nearest to and: or, but, in, at, who, however, superficial, interwiki,
# Nearest to used: allowed, condemn, koza, known, found, judgments, rises, spacecraft,
# Nearest to or: and, than, capitol, but, mambo, pleasures, higham, unverified,
# Nearest to th: reisman, bc, hours, asparagales, symphonie, nd, kryptonian, rome,
# Nearest to which: that, who, this, also, but, now, it, these,
# Nearest to it: he, this, there, they, she, not, which, still,
# Nearest to these: some, many, sissy, several, which, all, they, other,
# Nearest to by: in, be, with, for, without, halliwell, from, were,
# Nearest to such: well, known, modality, other, viscous, classified, certain, canetti,
# Average loss at step 22000: 3.503243
# Average loss at step 24000: 3.492985
# Average loss at step 26000: 3.483931
# Average loss at step 28000: 3.482566
# Average loss at step 30000: 3.504182
# Nearest to zero: five, eight, seven, three, four, six, nine, two,
# Nearest to on: in, through, bioko, at, upon, about, into, conserved,
# Nearest to to: would, will, can, against, could, shall, mcdonald, inhuman,
# Nearest to into: from, within, ecusa, ascendancy, biennial, valencia, idris, cinema,
# Nearest to were: are, have, was, had, been, ceramics, is, these,
# Nearest to been: be, become, was, were, diminution, by, had, untersuchungen,
# Nearest to seven: eight, nine, five, four, six, three, two, zero,
# Nearest to and: or, in, but, however, who, from, ivies, capt,
# Nearest to used: allowed, written, condemn, found, known, koza, considered, available,
# Nearest to or: and, than, but, minigun, superficial, capitol, mlm, mills,
# Nearest to th: bc, nd, hours, six, asparagales, reisman, two, symphonie,
# Nearest to which: this, that, also, but, what, it, who, these,
# Nearest to it: he, there, this, she, they, not, which, still,
# Nearest to these: some, many, several, sissy, their, they, such, all,
# Nearest to by: was, in, with, without, were, surinam, greatest, been,
# Nearest to such: well, known, these, other, modality, certain, some, viscous,
# Average loss at step 32000: 3.502625
# Average loss at step 34000: 3.498756
# Average loss at step 36000: 3.452705
# Average loss at step 38000: 3.303704
# Average loss at step 40000: 3.428805
# Nearest to zero: seven, five, nine, eight, four, six, three, two,
# Nearest to on: at, upon, through, in, against, uno, conserved, bioko,
# Nearest to to: might, could, libation, will, wail, must, pickens, can,
# Nearest to into: from, through, ecusa, biennial, within, idris, ascendancy, around,
# Nearest to were: are, have, was, been, be, these, reparation, when,
# Nearest to been: be, become, was, were, had, mazarin, previously, untersuchungen,
# Nearest to seven: eight, five, nine, six, four, three, zero, two,
# Nearest to and: or, but, superficial, in, like, lip, milgram, while,
# Nearest to used: found, allowed, written, known, considered, condemn, available, referred,
# Nearest to or: and, than, but, mambo, romanian, radii, elevating, pitot,
# Nearest to th: bc, nd, hours, asparagales, reisman, twentieth, symphonie, ferrari,
# Nearest to which: that, this, also, but, who, it, what, there,
# Nearest to it: he, there, she, this, they, which, still, not,
# Nearest to these: many, some, several, those, such, sissy, which, both,
# Nearest to by: without, lags, as, with, adf, when, be, radii,
# Nearest to such: well, known, certain, these, modality, parked, attica, many,
# Average loss at step 42000: 3.435737
# Average loss at step 44000: 3.455790
# Average loss at step 46000: 3.455080
# Average loss at step 48000: 3.351146
# Average loss at step 50000: 3.384711
# Nearest to zero: seven, five, eight, nine, six, four, three, two,
# Nearest to on: upon, through, in, at, bioko, gurmukhi, variances, pmrc,
# Nearest to to: would, could, maliki, may, will, microelectronics, can, against,
# Nearest to into: from, through, ecusa, biennial, ascendancy, within, cinema, around,
# Nearest to were: are, was, have, be, been, had, moby, although,
# Nearest to been: become, be, was, had, were, ideologically, gravel, mazarin,
# Nearest to seven: eight, six, nine, four, five, three, zero, one,
# Nearest to and: or, but, superficial, interwiki, however, including, ivies, guitars,
# Nearest to used: written, known, referred, considered, allowed, found, available, added,
# Nearest to or: and, than, mills, spaced, guitars, foretold, but, officio,
# Nearest to th: bc, nd, asparagales, one, symphonie, twentieth, ferrari, eight,
# Nearest to which: that, this, also, now, who, what, but, still,
# Nearest to it: he, there, she, this, they, now, still, not,
# Nearest to these: some, many, several, such, both, those, various, sissy,
# Nearest to by: was, through, newly, adf, nucleosome, without, under, surinam,
# Nearest to such: well, known, these, certain, parked, modality, many, coaching,
# Average loss at step 52000: 3.436727
# Average loss at step 54000: 3.427923
# Average loss at step 56000: 3.442044
# Average loss at step 58000: 3.398683
# Average loss at step 60000: 3.392587
# Nearest to zero: five, four, seven, six, eight, nine, three, two,
# Nearest to on: upon, through, bioko, at, in, pmrc, gb, about,
# Nearest to to: maliki, would, must, will, might, famagusta, batsman, pickens,
# Nearest to into: from, through, within, ecusa, biennial, ascendancy, around, over,
# Nearest to were: are, was, have, although, had, be, reparation, while,
# Nearest to been: become, be, was, had, ideologically, previously, were, mazarin,
# Nearest to seven: eight, four, six, nine, five, three, zero, two,
# Nearest to and: or, but, than, permittivity, although, however, maliki, in,
# Nearest to used: known, written, considered, found, referred, available, allowed, called,
# Nearest to or: and, than, precambrian, yetzirah, waterfalls, but, mambo, spaced,
# Nearest to th: bc, nd, twentieth, eight, ferrari, asparagales, seven, bce,
# Nearest to which: that, this, what, these, also, it, but, constitutive,
# Nearest to it: he, there, she, this, which, they, now, still,
# Nearest to these: many, some, several, those, such, various, which, both,
# Nearest to by: without, through, adf, including, was, from, nucleosome, gos,
# Nearest to such: well, known, these, certain, parked, many, severe, agitated,
# Average loss at step 62000: 3.240523
# Average loss at step 64000: 3.257675
# Average loss at step 66000: 3.398893
# Average loss at step 68000: 3.399276
# Average loss at step 70000: 3.359067
# Nearest to zero: five, eight, six, four, seven, nine, three, two,
# Nearest to on: upon, through, in, within, amazement, at, pmrc, bioko,
# Nearest to to: will, maliki, would, and, can, may, pickens, against,
# Nearest to into: through, from, ecusa, within, biennial, around, icftu, ingress,
# Nearest to were: are, was, have, had, although, these, be, reparation,
# Nearest to been: become, be, was, previously, were, had, already, mazarin,
# Nearest to seven: six, eight, four, nine, five, three, two, zero,
# Nearest to and: or, but, while, superficial, to, which, like, however,
# Nearest to used: known, available, found, written, allowed, referred, considered, involved,
# Nearest to or: and, than, any, but, ogdoad, while, spaced, precambrian,
# Nearest to th: bc, ferrari, twentieth, nd, six, asparagales, seven, one,
# Nearest to which: that, this, also, what, but, these, typically, usually,
# Nearest to it: he, she, there, this, they, still, we, usually,
# Nearest to these: many, some, such, several, various, sissy, those, their,
# Nearest to by: without, through, in, from, be, was, including, stilicho,
# Nearest to such: well, these, known, certain, parked, severe, classified, many,
# Average loss at step 72000: 3.376307
# Average loss at step 74000: 3.348696
# Average loss at step 76000: 3.315131
# Average loss at step 78000: 3.357123
# Average loss at step 80000: 3.380925
# Nearest to zero: five, seven, four, six, eight, three, nine, two,
# Nearest to on: upon, through, in, at, poetess, bioko, within, pmrc,
# Nearest to to: would, commotion, maliki, should, haag, doherty, will, could,
# Nearest to into: through, from, ecusa, within, icftu, ingress, around, biennial,
# Nearest to were: are, was, had, have, be, those, been, being,
# Nearest to been: become, be, was, had, previously, were, mazarin, already,
# Nearest to seven: eight, six, five, four, nine, three, zero, two,
# Nearest to and: or, while, including, oman, but, adrian, marc, heuristic,
# Nearest to used: known, written, considered, allowed, referred, found, available, required,
# Nearest to or: and, than, while, but, starks, pavel, schmidt, non,
# Nearest to th: bc, twentieth, nd, ferrari, three, five, one, asparagales,
# Nearest to which: this, that, what, usually, also, typically, auk, burlington,
# Nearest to it: he, she, there, this, they, we, itself, still,
# Nearest to these: several, many, those, various, such, some, sissy, their,
# Nearest to by: through, including, norodom, rfc, verisimilitude, newly, benefitting, odie,
# Nearest to such: well, certain, these, known, classified, including, follows, severe,
# Average loss at step 82000: 3.412186
# Average loss at step 84000: 3.410855
# Average loss at step 86000: 3.388378
# Average loss at step 88000: 3.355656
# Average loss at step 90000: 3.368762
# Nearest to zero: five, eight, seven, four, six, three, nine, two,
# Nearest to on: upon, through, in, under, prefectures, at, pmrc, within,
# Nearest to to: would, will, maliki, doherty, acls, pickens, kingman, inhuman,
# Nearest to into: through, from, ecusa, biennial, ingress, icftu, within, down,
# Nearest to were: are, had, was, have, while, those, although, reparation,
# Nearest to been: become, be, was, already, previously, mazarin, gravel, had,
# Nearest to seven: eight, six, four, five, nine, three, zero, two,
# Nearest to and: or, but, while, including, spoof, superficial, by, sadi,
# Nearest to used: known, allowed, considered, referred, required, found, added, written,
# Nearest to or: and, than, pavel, lahore, but, kleine, yetzirah, while,
# Nearest to th: bc, twentieth, one, eight, nd, ferrari, seven, three,
# Nearest to which: that, this, also, what, usually, typically, these, but,
# Nearest to it: he, she, there, this, they, itself, we, actually,
# Nearest to these: several, some, many, various, are, such, those, sissy,
# Nearest to by: without, through, while, when, norodom, verisimilitude, being, using,
# Nearest to such: well, known, certain, these, follows, including, classified, attica,
# Average loss at step 92000: 3.395886
# Average loss at step 94000: 3.257890
# Average loss at step 96000: 3.356717
# Average loss at step 98000: 3.240898
# Average loss at step 100000: 3.353756
# Nearest to zero: five, four, eight, seven, six, three, nine, two,
# Nearest to on: upon, through, at, in, within, pmrc, bioko, against,
# Nearest to to: could, would, will, must, can, and, should, may,
# Nearest to into: through, from, ecusa, within, biennial, icftu, hypnos, down,
# Nearest to were: are, was, have, had, those, although, including, these,
# Nearest to been: become, be, was, already, gravel, previously, had, mazarin,
# Nearest to seven: eight, nine, six, four, five, three, zero, two,
# Nearest to and: but, or, while, however, abul, to, although, oman,
# Nearest to used: allowed, found, considered, referred, known, written, held, constructed,
# Nearest to or: and, than, starks, unjustly, mambo, pavel, any, yetzirah,
# Nearest to th: bc, twentieth, nd, ferrari, asparagales, rd, kryptonian, odyssey,
# Nearest to which: that, this, usually, typically, what, also, but, these,
# Nearest to it: he, she, this, there, they, never, itself, actually,
# Nearest to these: several, some, many, various, those, all, certain, examples,
# Nearest to by: including, through, without, when, from, nucleosome, textile, lumley,
# Nearest to such: well, known, certain, many, these, attica, including, lubricated,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_cbow_batch(batch_size, context_window):
  global data_index

  context_size = 2 * context_window
  batch = np.ndarray(shape=(batch_size, context_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)

  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)

  for i in range(batch_size):
    to_copy = [token for idx, token in enumerate(buffer) if idx != context_window]
    batch[i, :] = to_copy
    labels[i, 0] = buffer[context_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)

  return batch, labels

batch, labels = generate_cbow_batch(batch_size=8, context_window=1)

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
context_window = 1 # How many words to consider left and right.
context_size = 2 * context_window

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, context_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  embed_context = tf.reduce_mean(embed, 1)

  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed_context,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')

  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_cbow_batch(batch_size, context_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}

    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l

    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0

    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.306898
# Nearest to over: majorana, hispanic, harnack, victories, ivorian, multilinear, madison, attained,
# Nearest to more: lovin, burnham, pride, demand, heartland, rarefied, napkin, vein,
# Nearest to most: nave, cory, muslim, happens, excavated, burying, circle, predicting,
# Nearest to when: conscripted, promises, psychedelic, interacted, assures, domine, comparatively, aronson,
# Nearest to years: setting, cent, librivox, mistranslation, queen, opencourseware, mya, behalf,
# Nearest to on: subtly, elliptic, astigmatism, lithium, tourists, nineteenth, diurnal, rearmament,
# Nearest to has: aide, merril, appearances, hundreds, snapshots, beersheba, scripted, endocrinology,
# Nearest to s: reorganize, store, lavin, uematsu, ryaku, webzine, removed, xinhua,
# Nearest to had: treatment, informal, recorded, sanderson, malls, hybridized, transhumanism, centaurs,
# Nearest to new: rale, audit, bankruptcies, flavian, partying, codata, cardiovascular, eln,
# Nearest to it: trajectory, bought, morel, suspense, pineal, travelogues, counsel, brahma,
# Nearest to state: tursiops, certification, latterly, addons, chinook, snipers, bok, magog,
# Nearest to not: premierships, acquis, decameron, bureaucrat, occupies, ethicists, nhs, intrepid,
# Nearest to are: csi, disapproved, skipping, chalice, boopsie, latin, descend, boutique,
# Nearest to i: exiling, racketeering, rohrabacher, fanfare, destroyed, coherence, yeti, yiddish,
# Nearest to five: superlative, perceptible, playback, sculpted, sorghum, aeneid, yoshitaka, severely,
# Average loss at step 2000: 4.032704
# Average loss at step 4000: 3.501984
# Average loss at step 6000: 3.342645
# Average loss at step 8000: 3.192212
# Average loss at step 10000: 3.144210
# Nearest to over: majorana, hispanic, specialized, solar, cola, ivorian, within, atheistic,
# Nearest to more: burnham, toxin, lovin, less, examples, ostrich, fingerspelling, pride,
# Nearest to most: burying, muslim, cory, land, excavated, nave, kaposi, potent,
# Nearest to when: aronson, mentor, if, since, predynastic, expenditure, where, pretty,
# Nearest to years: behalf, mistranslation, subproblems, persuading, queen, reach, voluntary, librivox,
# Nearest to on: in, leninist, reaper, subtly, astigmatism, radiocommunication, zia, holmium,
# Nearest to has: had, was, have, is, covenants, mandeville, mitford, cloudy,
# Nearest to s: reorganize, conserving, hesse, uematsu, researching, secondarily, franchises, arias,
# Nearest to had: has, have, was, were, covenants, having, merina, scarp,
# Nearest to new: rangoon, rale, audit, relevant, yuri, interrogated, reviewing, codata,
# Nearest to it: he, this, there, she, we, bought, counsel, they,
# Nearest to state: spared, lenient, enigmas, gua, tursiops, national, imaging, semblance,
# Nearest to not: also, bureaucrat, acquis, interested, servicemen, publique, decameron, nhs,
# Nearest to are: were, is, csi, have, ayers, descend, rubidium, denaturation,
# Nearest to i: you, exiling, feeders, whitehouse, yiddish, we, iliad, handedly,
# Nearest to five: six, nine, three, eight, zero, seven, four, two,
# Average loss at step 12000: 3.170084
# Average loss at step 14000: 3.121257
# Average loss at step 16000: 3.145756
# Average loss at step 18000: 3.101669
# Average loss at step 20000: 2.996198
# Nearest to over: solar, majorana, within, sustainability, pontifex, almost, ivorian, specialized,
# Nearest to more: less, most, better, toxin, ostrich, suede, burnham, pride,
# Nearest to most: more, burying, some, excavated, kaposi, nave, land, cory,
# Nearest to when: if, where, after, since, amygdala, though, aronson, mentor,
# Nearest to years: months, behalf, subproblems, persuading, centuries, mistranslation, oz, reach,
# Nearest to on: upon, in, holmium, around, reaper, about, omniscient, under,
# Nearest to has: had, have, was, is, mandeville, cloudy, mitford, covenants,
# Nearest to s: his, unconsciousness, reorganize, conserving, uematsu, hesse, thomas, atone,
# Nearest to had: has, have, was, having, were, covenants, scarp, playlists,
# Nearest to new: rale, rangoon, recruited, interrogated, relevant, yuri, audit, reviewing,
# Nearest to it: he, she, this, there, we, counsel, saviour, intrusion,
# Nearest to state: national, spared, gua, naxos, central, tursiops, lenient, reluctantly,
# Nearest to not: bureaucrat, interested, also, still, numbered, publique, acquis, bankrupt,
# Nearest to are: were, have, is, be, include, ayers, denaturation, touchdown,
# Nearest to i: you, we, iliad, he, they, feeders, handedly, yiddish,
# Nearest to five: six, four, eight, seven, three, nine, zero, two,
# Average loss at step 22000: 3.054710
# Average loss at step 24000: 3.025265
# Average loss at step 26000: 2.986718
# Average loss at step 28000: 3.010102
# Average loss at step 30000: 2.986620
# Nearest to over: solar, sustainability, around, within, british, screename, majorana, ivorian,
# Nearest to more: less, most, better, suede, ostrich, toxin, fingerspelling, leiber,
# Nearest to most: more, some, many, excavated, other, burying, coler, nave,
# Nearest to when: if, after, where, amygdala, since, before, though, because,
# Nearest to years: months, days, behalf, times, centuries, persuading, subproblems, sticker,
# Nearest to on: upon, in, regarding, about, through, astigmatism, across, omniscient,
# Nearest to has: had, have, is, was, having, tombalbaye, covenants, mandeville,
# Nearest to s: reorganize, unconsciousness, thomas, uematsu, his, collisions, turmeric, sometime,
# Nearest to had: has, have, was, having, were, sought, covenants, scarp,
# Nearest to new: rale, rangoon, interrogated, german, eiji, yuri, relevant, cheng,
# Nearest to it: he, she, this, there, counsel, intrusion, they, what,
# Nearest to state: national, spared, tursiops, workbench, definition, intact, gast, gua,
# Nearest to not: still, bureaucrat, actually, interested, publique, almost, to, generally,
# Nearest to are: were, have, is, include, be, ayers, denaturation, touchdown,
# Nearest to i: you, we, iliad, feeders, ii, handedly, commutative, coughlin,
# Nearest to five: four, six, eight, three, seven, nine, two, zero,
# Average loss at step 32000: 2.839862
# Average loss at step 34000: 2.943358
# Average loss at step 36000: 2.940689
# Average loss at step 38000: 2.936059
# Average loss at step 40000: 2.921222
# Nearest to over: within, solar, around, screename, sustainability, almost, boost, majorana,
# Nearest to more: less, most, better, suede, highly, ostrich, burnham, toxin,
# Nearest to most: more, some, many, excavated, less, glace, particularly, licensees,
# Nearest to when: if, after, because, before, where, though, amygdala, since,
# Nearest to years: months, days, centuries, behalf, times, seven, decades, persuading,
# Nearest to on: upon, through, regarding, towards, mikl, omniscient, in, about,
# Nearest to has: had, have, is, was, having, mandeville, cl, includes,
# Nearest to s: reorganize, unconsciousness, thomas, turmeric, conserving, riemannian, encircle, sometime,
# Nearest to had: has, have, was, having, were, became, covenants, includes,
# Nearest to new: rale, exhibits, german, rangoon, cheng, yuri, charlestown, interrogated,
# Nearest to it: he, she, this, there, we, they, counsel, intrusion,
# Nearest to state: national, spared, carta, bok, government, definition, pyrotechnics, moose,
# Nearest to not: still, bureaucrat, dane, interested, actually, publique, ladies, almost,
# Nearest to are: were, have, is, include, be, ayers, instantaneously, denaturation,
# Nearest to i: you, we, UNK, iliad, ii, handedly, coughlin, coherence,
# Nearest to five: six, four, seven, three, eight, nine, zero, two,
# Average loss at step 42000: 2.938778
# Average loss at step 44000: 2.943010
# Average loss at step 46000: 2.907608
# Average loss at step 48000: 2.867161
# Average loss at step 50000: 2.846628
# Nearest to over: around, within, solar, screename, pontifex, almost, sustainability, jawaharlal,
# Nearest to more: less, most, better, highly, suede, rather, toxin, extremely,
# Nearest to most: more, many, some, less, excavated, especially, several, particularly,
# Nearest to when: if, after, before, where, though, because, during, amygdala,
# Nearest to years: months, days, centuries, times, behalf, decades, minutes, persuading,
# Nearest to on: upon, in, regarding, disillusionment, towards, through, about, under,
# Nearest to has: had, have, is, was, includes, revitalized, having, contains,
# Nearest to s: unconsciousness, ucr, conserving, valign, riemannian, isbn, usemodwiki, encircle,
# Nearest to had: has, have, was, were, having, sought, since, investigated,
# Nearest to new: exhibits, rale, rangoon, yuri, charlestown, recruited, comoros, schwartz,
# Nearest to it: he, this, she, there, they, hello, nothing, counsel,
# Nearest to state: national, states, government, pyrotechnics, workbench, spared, distract, chateau,
# Nearest to not: still, actually, otherwise, ladies, interested, never, generally, bureaucrat,
# Nearest to are: were, have, is, be, include, touchdown, appointments, instantaneously,
# Nearest to i: you, we, iliad, ii, commutative, feeders, g, handedly,
# Nearest to five: four, seven, six, eight, three, nine, zero, two,
# Average loss at step 52000: 2.881790
# Average loss at step 54000: 2.860091
# Average loss at step 56000: 2.857438
# Average loss at step 58000: 2.763493
# Average loss at step 60000: 2.827433
# Nearest to over: around, within, screename, solar, sustainability, almost, pentecostal, towards,
# Nearest to more: less, most, highly, better, rather, suede, very, toxin,
# Nearest to most: more, many, some, particularly, less, especially, excavated, glace,
# Nearest to when: if, after, where, before, though, because, during, while,
# Nearest to years: months, days, centuries, decades, times, minutes, behalf, year,
# Nearest to on: upon, towards, through, in, regarding, under, at, across,
# Nearest to has: had, have, is, was, includes, having, contains, kowtow,
# Nearest to s: unconsciousness, conserving, riemannian, inq, thomas, turmeric, my, cometary,
# Nearest to had: has, have, was, were, having, sought, eventually, since,
# Nearest to new: exhibits, rale, charlestown, recruited, interrogated, yuri, comoros, rangoon,
# Nearest to it: he, she, this, there, nothing, they, what, which,
# Nearest to state: states, national, government, pyrotechnics, senior, axiomatization, carta, kingdom,
# Nearest to not: actually, never, still, otherwise, bureaucrat, interested, always, almost,
# Nearest to are: were, is, have, include, including, be, touchdown, instantaneously,
# Nearest to i: you, we, iliad, ii, g, handedly, she, longbowmen,
# Nearest to five: seven, four, six, eight, nine, three, zero, two,
# Average loss at step 62000: 2.831893
# Average loss at step 64000: 2.785543
# Average loss at step 66000: 2.769560
# Average loss at step 68000: 2.721315
# Average loss at step 70000: 2.775056
# Nearest to over: around, within, screename, sustainability, solar, pentecostal, almost, blow,
# Nearest to more: less, most, better, highly, very, toxin, rather, quite,
# Nearest to most: many, more, some, particularly, less, especially, excavated, several,
# Nearest to when: if, after, before, though, where, amygdala, while, because,
# Nearest to years: months, days, centuries, decades, times, minutes, weeks, year,
# Nearest to on: upon, in, towards, through, omniscient, across, regarding, under,
# Nearest to has: had, have, is, was, includes, having, contains, appoints,
# Nearest to s: unconsciousness, his, conserving, your, rshavn, corgi, isbn, depicting,
# Nearest to had: has, have, was, having, were, sought, eventually, since,
# Nearest to new: exhibits, rale, atlantean, interrogated, recruited, repetitive, charlestown, yuri,
# Nearest to it: he, she, there, this, nothing, they, itself, katha,
# Nearest to state: states, national, government, pyrotechnics, dixon, chatham, distract, axiomatization,
# Nearest to not: otherwise, never, actually, always, bureaucrat, still, now, almost,
# Nearest to are: were, have, include, is, touchdown, including, appointments, nurse,
# Nearest to i: you, we, ii, g, iliad, longbowmen, handedly, bhopal,
# Nearest to five: seven, four, six, eight, three, nine, zero, two,
# Average loss at step 72000: 2.801489
# Average loss at step 74000: 2.659898
# Average loss at step 76000: 2.797276
# Average loss at step 78000: 2.820957
# Average loss at step 80000: 2.782276
# Nearest to over: around, within, pentecostal, solar, almost, sustainability, screename, blow,
# Nearest to more: less, most, highly, very, better, rather, quite, toxin,
# Nearest to most: more, many, some, particularly, less, especially, excavated, several,
# Nearest to when: if, after, though, before, where, during, while, amygdala,
# Nearest to years: months, days, centuries, decades, minutes, times, weeks, year,
# Nearest to on: upon, in, through, towards, regarding, around, at, under,
# Nearest to has: had, have, is, was, having, includes, contains, appoints,
# Nearest to s: corgi, unconsciousness, inq, isbn, your, riemannian, whose, encircle,
# Nearest to had: has, have, was, having, were, sought, showed, eventually,
# Nearest to new: exhibits, charlestown, rale, interrogated, kindred, rocker, recruited, yuri,
# Nearest to it: he, she, there, this, they, itself, nothing, today,
# Nearest to state: states, national, pyrotechnics, government, dixon, distract, chatham, strangeness,
# Nearest to not: otherwise, still, actually, never, bureaucrat, almost, interested, generally,
# Nearest to are: were, have, is, include, touchdown, be, including, ayers,
# Nearest to i: we, you, they, ii, iliad, longbowmen, she, g,
# Nearest to five: six, four, seven, eight, three, nine, two, zero,
# Average loss at step 82000: 2.674153
# Average loss at step 84000: 2.772594
# Average loss at step 86000: 2.744556
# Average loss at step 88000: 2.755822
# Average loss at step 90000: 2.742673
# Nearest to over: around, almost, within, solar, pentecostal, about, screename, sustainability,
# Nearest to more: less, most, highly, very, quite, extremely, better, rather,
# Nearest to most: more, some, many, less, particularly, especially, washing, all,
# Nearest to when: if, where, though, before, after, although, because, while,
# Nearest to years: months, days, centuries, decades, minutes, weeks, times, year,
# Nearest to on: upon, in, through, regarding, towards, around, cimbri, at,
# Nearest to has: had, have, is, was, kowtow, having, includes, cl,
# Nearest to s: whose, unconsciousness, isbn, riemannian, sometime, conserving, cometary, atone,
# Nearest to had: has, have, was, having, were, sought, investigated, recently,
# Nearest to new: exhibits, interrogated, comoros, old, charlestown, kindred, rale, yuri,
# Nearest to it: he, she, there, this, they, nothing, quickly, itself,
# Nearest to state: states, national, government, distract, dixon, pyrotechnics, chatham, navajo,
# Nearest to not: never, otherwise, actually, generally, almost, bureaucrat, always, still,
# Nearest to are: were, have, is, include, including, touchdown, nurse, instantaneously,
# Nearest to i: we, you, ii, they, iliad, g, she, venus,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Average loss at step 92000: 2.685358
# Average loss at step 94000: 2.728217
# Average loss at step 96000: 2.711155
# Average loss at step 98000: 2.382121
# Average loss at step 100000: 2.423548
# Nearest to over: around, within, screename, almost, pentecostal, blow, barada, solar,
# Nearest to more: less, most, highly, better, rather, very, quite, suede,
# Nearest to most: more, some, less, many, particularly, especially, precolonial, excavated,
# Nearest to when: if, after, before, where, though, amygdala, although, because,
# Nearest to years: months, days, decades, centuries, minutes, weeks, year, times,
# Nearest to on: upon, in, through, regarding, towards, around, at, reaper,
# Nearest to has: had, have, is, was, having, includes, contains, kowtow,
# Nearest to s: unconsciousness, conserving, american, inq, isbn, turmeric, whose, thomas,
# Nearest to had: has, have, was, having, were, sought, recently, showed,
# Nearest to new: exhibits, comoros, interrogated, charlestown, rocker, certificate, schwartz, atlantean,
# Nearest to it: he, she, this, there, they, nothing, never, itself,
# Nearest to state: states, national, government, distract, pyrotechnics, bureau, chatham, dixon,
# Nearest to not: never, otherwise, actually, bureaucrat, always, still, almost, parliaments,
# Nearest to are: were, have, include, is, including, be, touchdown, iia,
# Nearest to i: you, we, ii, iliad, they, g, longbowmen, venus,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
