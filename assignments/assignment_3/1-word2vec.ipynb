# %% [markdown]
# Deep Learning
# =============
#
# Assignment 3.1
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline

import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'a', 'originated', 'as', 'of', 'term', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From /home/ivanasen/Tools/anaconda3/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/ivanasen/Tools/anaconda3/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1444: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /home/ivanasen/Tools/anaconda3/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.732253
# Nearest to most: ponies, executioner, iraq, tumultuous, distances, seaside, phosphate, zhang,
# Nearest to two: isca, documentaries, onion, asatru, further, committed, equipment, presenter,
# Nearest to they: wachowski, laertius, mossi, federations, cdg, shortwave, returner, subtext,
# Nearest to such: bouldering, lucifer, wanda, sequencer, recommends, carbines, superiority, gilt,
# Nearest to i: irritant, landfill, quipped, berio, gloss, wormhole, ashford, einer,
# Nearest to many: lading, perrin, chemical, bills, embarrassment, lichens, atomists, stiles,
# Nearest to some: prior, derivates, starve, undone, hecuba, rcn, borrowers, gbp,
# Nearest to when: dyson, twa, maximizes, wand, capricorn, chromium, wwi, bowdoin,
# Nearest to into: guinean, lived, specialize, hern, barisan, screech, quite, pohnpei,
# Nearest to more: wealthy, discovers, functionalists, ungrammatical, nepal, cpus, wedded, bock,
# Nearest to are: bokken, dichotomy, tenant, northside, apes, aerobatics, catchphrase, eea,
# Nearest to it: imaginable, calvert, fiend, woolwich, sentient, georgetown, ralph, netsplit,
# Nearest to system: suspicion, heartbroken, iupac, reference, greenland, tax, bastille, homogenous,
# Nearest to he: yung, cardamom, reaper, mourns, donaghy, deployments, katharine, variably,
# Nearest to their: ghosts, cdma, appreciated, consecrations, kuleshov, wiesenthal, ebro, lucille,
# Nearest to and: shortwave, trivia, ffff, mustaine, crassus, talons, soundtracks, spectators,
# Average loss at step 2000: 4.372140
# Average loss at step 4000: 3.862846
# Average loss at step 6000: 3.785104
# Average loss at step 8000: 3.691319
# Average loss at step 10000: 3.616121
# Nearest to most: ponies, zhang, cyberpunk, distances, other, liao, seaside, oglethorpe,
# Nearest to two: three, five, four, six, eight, nine, zero, seven,
# Nearest to they: he, there, we, it, she, not, politico, wachowski,
# Nearest to such: wanda, bouldering, creamy, well, these, saba, tiraspol, sequencer,
# Nearest to i: erased, irritant, wormhole, gloss, sidney, berio, traditionalists, overheat,
# Nearest to many: some, all, charlottenburg, pottery, occur, bills, gaming, unauthorised,
# Nearest to some: many, these, all, junctions, solidifies, wren, israeli, hee,
# Nearest to when: wwi, maximizes, derleth, twa, felt, browse, aggrieved, before,
# Nearest to into: from, as, statehouse, polarity, badlands, varphi, callisto, limit,
# Nearest to more: esaf, wealthy, benefited, voss, very, philosophical, frazee, neh,
# Nearest to are: were, is, have, cogent, nautilus, foldoc, like, reactants,
# Nearest to it: he, this, there, which, that, they, not, but,
# Nearest to system: iupac, greenland, nen, microscopes, suspicion, cromwell, tax, preprocessing,
# Nearest to he: it, they, she, there, balkan, who, regiments, metamorphic,
# Nearest to their: his, the, its, ghosts, juvenal, happens, orders, quickly,
# Nearest to and: or, complexities, s, kulaks, alton, who, like, soviets,
# Average loss at step 12000: 3.605555
# Average loss at step 14000: 3.569884
# Average loss at step 16000: 3.409009
# Average loss at step 18000: 3.457528
# Average loss at step 20000: 3.541830
# Nearest to most: liao, zhang, more, some, cyberpunk, ponies, use, monsieur,
# Nearest to two: three, five, four, six, one, eight, seven, nine,
# Nearest to they: he, we, there, it, you, she, who, not,
# Nearest to such: these, well, known, wanda, creamy, polytheism, gilt, much,
# Nearest to i: ii, wormhole, irritant, you, overheat, they, intersects, erased,
# Nearest to many: some, other, all, these, various, several, prosecutors, their,
# Nearest to some: many, these, all, other, their, several, most, the,
# Nearest to when: if, after, where, twa, pituitary, browse, aggrieved, before,
# Nearest to into: from, by, statehouse, amassed, rinzai, vaughn, callisto, epicurus,
# Nearest to more: very, less, voss, esaf, most, lancelot, neh, ffffff,
# Nearest to are: were, is, have, colonisation, was, navel, altered, sp,
# Nearest to it: he, there, this, they, which, she, betrothed, not,
# Nearest to system: greenland, cromwell, configure, nen, booster, microscopes, suspicion, superfund,
# Nearest to he: it, she, they, who, there, balkan, never, echoing,
# Nearest to their: his, its, her, the, some, paucity, juvenal, up,
# Nearest to and: or, in, but, skye, which, for, from, caucus,
# Average loss at step 22000: 3.507751
# Average loss at step 24000: 3.489292
# Average loss at step 26000: 3.483530
# Average loss at step 28000: 3.479585
# Average loss at step 30000: 3.502042
# Nearest to most: some, liao, more, many, use, zhang, mesogens, android,
# Nearest to two: three, four, one, five, six, seven, eight, zero,
# Nearest to they: there, we, he, you, it, who, she, not,
# Nearest to such: well, these, known, wanda, follows, some, knowledgeable, crook,
# Nearest to i: ii, you, wormhole, we, overheat, rosh, sidney, courting,
# Nearest to many: some, several, these, various, all, their, enlarge, other,
# Nearest to some: many, these, several, their, all, other, any, most,
# Nearest to when: if, after, before, where, during, although, was, though,
# Nearest to into: from, statehouse, through, rinzai, buddies, vaughn, epicurus, hewson,
# Nearest to more: less, very, voss, most, lancelot, airspace, esaf, benefited,
# Nearest to are: were, have, is, include, be, malinche, these, includes,
# Nearest to it: he, there, this, she, they, which, mired, not,
# Nearest to system: cromwell, nen, brahmagupta, configure, superfund, parole, booster, microscopes,
# Nearest to he: she, it, they, who, there, balkan, never, but,
# Nearest to their: his, its, the, her, some, these, many, our,
# Nearest to and: or, but, in, who, insulinotherapy, moc, he, from,
# Average loss at step 32000: 3.504318
# Average loss at step 34000: 3.491205
# Average loss at step 36000: 3.452247
# Average loss at step 38000: 3.296540
# Average loss at step 40000: 3.429984
# Nearest to most: more, liao, some, many, monsieur, zhang, android, otter,
# Nearest to two: three, four, five, seven, six, one, eight, nine,
# Nearest to they: we, there, he, you, it, she, these, who,
# Nearest to such: well, these, known, wanda, follows, coalescence, some, tribunes,
# Nearest to i: you, ii, we, t, wormhole, they, overheat, he,
# Nearest to many: some, several, these, various, enlarge, drawers, both, most,
# Nearest to some: many, these, any, several, various, their, most, both,
# Nearest to when: if, where, before, while, after, during, because, was,
# Nearest to into: from, through, statehouse, amassed, vaughn, armouries, rinzai, battling,
# Nearest to more: less, very, most, voss, lancelot, longer, frazee, anisotropic,
# Nearest to are: were, have, is, but, navel, while, includes, can,
# Nearest to it: he, there, she, this, they, which, not, still,
# Nearest to system: systems, nen, booster, bastille, obeyed, cromwell, brahmagupta, puzzled,
# Nearest to he: she, it, they, who, there, never, this, numismatics,
# Nearest to their: his, its, her, the, our, any, some, them,
# Nearest to and: or, but, in, complexities, philippine, like, unesco, mei,
# Average loss at step 42000: 3.437676
# Average loss at step 44000: 3.450924
# Average loss at step 46000: 3.453863
# Average loss at step 48000: 3.358257
# Average loss at step 50000: 3.385923
# Nearest to most: more, liao, many, bantu, some, use, other, android,
# Nearest to two: three, four, six, five, one, seven, eight, zero,
# Nearest to they: we, he, there, you, she, it, these, who,
# Nearest to such: these, well, known, many, tribunes, wanda, much, approves,
# Nearest to i: you, we, ii, wormhole, overheat, t, ashoka, they,
# Nearest to many: some, several, these, various, both, much, such, those,
# Nearest to some: many, these, several, any, both, various, their, other,
# Nearest to when: if, after, while, before, where, although, but, though,
# Nearest to into: through, from, buddies, rinzai, vaughn, over, amassed, during,
# Nearest to more: less, most, very, lancelot, voss, longer, faster, highly,
# Nearest to are: were, is, have, be, these, was, sp, include,
# Nearest to it: he, there, she, this, they, which, still, pavement,
# Nearest to system: systems, bastille, nen, booster, rak, cromwell, olympiad, brahmagupta,
# Nearest to he: she, it, they, who, there, mired, we, this,
# Nearest to their: its, his, her, the, your, some, our, any,
# Nearest to and: or, but, including, complexities, of, quantitative, whose, aki,
# Average loss at step 52000: 3.436455
# Average loss at step 54000: 3.425672
# Average loss at step 56000: 3.440642
# Average loss at step 58000: 3.395304
# Average loss at step 60000: 3.396772
# Nearest to most: many, more, use, liao, some, among, other, necks,
# Nearest to two: three, four, six, one, five, eight, seven, zero,
# Nearest to they: we, there, you, he, she, it, these, not,
# Nearest to such: these, well, known, many, petition, including, regarded, tribunes,
# Nearest to i: you, we, ii, t, they, ashoka, overheat, wormhole,
# Nearest to many: some, several, various, these, both, most, such, drawers,
# Nearest to some: many, several, these, any, this, various, both, most,
# Nearest to when: if, although, while, before, where, because, after, during,
# Nearest to into: through, from, over, within, buddies, in, rinzai, armouries,
# Nearest to more: less, very, lancelot, most, longer, voss, faster, better,
# Nearest to are: were, is, have, although, be, includes, include, including,
# Nearest to it: he, there, she, this, they, which, now, still,
# Nearest to system: systems, nen, bastille, booster, olympiad, obeyed, azad, assistants,
# Nearest to he: she, it, they, who, there, we, later, mired,
# Nearest to their: its, his, her, the, our, your, them, some,
# Nearest to and: or, but, than, including, while, somewhat, rosicrucian, in,
# Average loss at step 62000: 3.237098
# Average loss at step 64000: 3.250732
# Average loss at step 66000: 3.407781
# Average loss at step 68000: 3.395044
# Average loss at step 70000: 3.358513
# Nearest to most: more, use, less, many, some, among, liao, bantu,
# Nearest to two: three, four, six, one, five, seven, eight, zero,
# Nearest to they: we, there, he, you, it, she, these, not,
# Nearest to such: these, well, known, certain, many, tribunes, gx, regarded,
# Nearest to i: we, you, ii, g, rosh, t, catiline, ashoka,
# Nearest to many: some, several, various, these, both, all, most, such,
# Nearest to some: many, several, these, various, any, their, this, all,
# Nearest to when: if, while, where, before, because, after, unto, although,
# Nearest to into: from, through, within, buddies, over, under, senussi, across,
# Nearest to more: less, most, very, faster, voss, longer, lancelot, quite,
# Nearest to are: were, have, is, include, although, these, including, includes,
# Nearest to it: he, she, there, this, they, which, still, betrothed,
# Nearest to system: systems, berliners, obeyed, marxist, resemble, booster, bastille, argument,
# Nearest to he: she, it, they, there, who, soon, we, mired,
# Nearest to their: its, his, her, the, our, your, some, these,
# Nearest to and: or, while, which, of, but, than, like, kulaks,
# Average loss at step 72000: 3.374649
# Average loss at step 74000: 3.349341
# Average loss at step 76000: 3.317325
# Average loss at step 78000: 3.353995
# Average loss at step 80000: 3.379433
# Nearest to most: more, many, some, use, among, less, bantu, bachelor,
# Nearest to two: three, four, six, seven, five, one, eight, zero,
# Nearest to they: we, he, there, you, she, it, these, lagenorhynchus,
# Nearest to such: these, well, certain, known, follows, coalescence, treated, tribunes,
# Nearest to i: ii, we, you, iii, catiline, ashoka, g, preprint,
# Nearest to many: some, several, various, these, most, both, all, those,
# Nearest to some: many, several, various, any, certain, these, most, both,
# Nearest to when: if, before, after, while, although, though, where, unto,
# Nearest to into: through, from, across, within, over, buddies, rinzai, down,
# Nearest to more: less, very, most, quite, faster, voss, frazee, longer,
# Nearest to are: were, have, include, is, although, while, these, be,
# Nearest to it: he, she, there, this, they, itself, still, betrothed,
# Nearest to system: systems, berliners, booster, resemble, azad, model, belize, transmission,
# Nearest to he: she, it, they, there, who, never, soon, mired,
# Nearest to their: its, his, her, your, our, the, some, these,
# Nearest to and: or, but, including, while, than, drown, hortense, mike,
# Average loss at step 82000: 3.411103
# Average loss at step 84000: 3.409145
# Average loss at step 86000: 3.394073
# Average loss at step 88000: 3.352056
# Average loss at step 90000: 3.365969
# Nearest to most: many, more, some, less, among, especially, use, particularly,
# Nearest to two: three, four, five, seven, six, one, eight, nine,
# Nearest to they: we, there, he, you, she, it, not, these,
# Nearest to such: well, known, these, certain, follows, treated, described, regarded,
# Nearest to i: we, you, ii, g, catiline, rajiv, iv, menelik,
# Nearest to many: some, several, various, these, most, numerous, all, both,
# Nearest to some: many, several, any, these, both, certain, most, various,
# Nearest to when: if, while, before, after, where, although, without, though,
# Nearest to into: through, from, within, across, rinzai, down, senussi, buddies,
# Nearest to more: less, very, most, faster, voss, quite, longer, better,
# Nearest to are: were, is, include, have, these, contain, although, those,
# Nearest to it: he, she, this, there, they, actually, betrothed, which,
# Nearest to system: systems, azad, belize, transmission, argument, model, burgoyne, booster,
# Nearest to he: she, it, they, there, who, soon, later, mired,
# Nearest to their: its, his, her, our, your, my, the, them,
# Nearest to and: or, but, including, while, phoca, retreating, in, tabloids,
# Average loss at step 92000: 3.397827
# Average loss at step 94000: 3.257674
# Average loss at step 96000: 3.357042
# Average loss at step 98000: 3.244401
# Average loss at step 100000: 3.357383
# Nearest to most: more, less, especially, many, particularly, bachelor, android, use,
# Nearest to two: three, four, five, six, one, seven, eight, zero,
# Nearest to they: we, there, he, you, she, it, never, soon,
# Nearest to such: well, known, these, certain, follows, many, treated, regarded,
# Nearest to i: we, you, ii, menelik, never, preprint, t, rajiv,
# Nearest to many: some, several, various, these, numerous, all, most, enlarge,
# Nearest to some: many, several, any, these, certain, various, all, their,
# Nearest to when: while, if, although, where, before, after, because, though,
# Nearest to into: through, from, across, within, in, toward, off, senussi,
# Nearest to more: less, very, most, better, quite, enough, faster, voss,
# Nearest to are: were, have, include, is, while, although, these, be,
# Nearest to it: he, she, this, there, they, betrothed, what, legates,
# Nearest to system: systems, transmission, model, azad, berliners, cyclase, amplitude, argument,
# Nearest to he: she, it, they, who, we, there, mired, never,
# Nearest to their: its, his, her, our, your, the, some, them,
# Nearest to and: but, or, although, while, phoca, including, when, like,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
